# %%
# %run data_functions.py

path = '../tennis_atp/'
files = [path + 'atp_matches_'+str(year)+'.csv' for year in range(2018, 2021)]
rank = path + 'atp_rankings_current.csv'
top = 50

games = catch_all_games(files, rank, top)
games
# Out:
#     tourney_date tourney_level               score winner_id  winner_rank  \
# 0       20180101             A             6-4 6-4    200282        208.0
# 1       20180101             A      4-6 7-6(8) 6-3    105777          3.0
# 2       20180101             A         3-6 6-1 6-4    106401         21.0
# 3       20180101             A      5-7 6-2 7-6(8)    106432         48.0
# 4       20180101             A         2-6 7-5 7-5    105550         64.0
# 5       20180101             A             6-1 6-3    106432         48.0
# 6       20180101             A         6-4 3-6 6-4    126094         39.0
# 7       20180101             A         6-3 1-6 6-3    104792         46.0
# 8       20180101             A             6-3 7-5    126094         39.0
# 9       20180101             A             7-5 6-4    106233          5.0
# 10      20180101             A      6-2 4-6 7-6(2)    126094         39.0
# 11      20180101             A                 W/O    104792         46.0
# ...

# %%
# %run model_functions.py

player1 = [   1,          0]
player2 = [-0.5,  sqrt(3)/2]
player3 = [-0.5, -sqrt(3)/2]

print('Entre player1 e player2 temos', 1 - find_probability(player1, player2), 'para vitória do player2')
print('Entre player2 e player3 temos', 1 - find_probability(player2, player3), 'para vitória do player3')
print('Entre player3 e player1 temos', 1 - find_probability(player3, player1), 'para vitória do player1')
# Out:
# Entre player1 e player2 temos 0.7039179947206429 para vitória do player2
# Entre player2 e player3 temos 0.7039179947206429 para vitória do player3
# Entre player3 e player1 temos 0.7039179947206429 para vitória do player1

# %%
results = [[0, 1], [1, 2], [2, 1]]
players = [[1, 0], [-0.5, sqrt(3)/2], [-0.5, -sqrt(3)/2]]

# %%
likelihood(players, results)
# Out:
# 2.785331050711237
